# %%
import pandas as pd

base_cafe = pd.read_excel("base/base_cafe.xlsx", sheet_name="dados")

base_cafe.head()
# Out:
#     Código                                          Descrição Departamento  \
# 0  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 1  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 2  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 3   183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
# 4   183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
#
#       Categoria/Setor Marca  Famlíia  Código do Fabricante  Código de Barras  \
# 0  Básico da despensa    pa      NaN                   NaN     7896089013399
# 1  Básico da despensa    pa      NaN                   NaN     7896089013399
# 2  Básico da despensa    pa      NaN                   NaN     7896089013399
# 3  Básico da despensa    pa      NaN                   NaN     7896005801529
# 4  Básico da despensa    pa      NaN                   NaN     7896005801529
#
#    SKU Monitorado   Website Monitorado  \
# ...

# %%
base_cafe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1047 entries, 0 to 1046
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Código                        1047 non-null   int64
#  1   Descrição                     1047 non-null   str
#  2   Departamento                  429 non-null    str
#  3   Categoria/Setor               429 non-null    str
#  4   Marca                         1047 non-null   str
#  5   Famlíia                       0 non-null      float64
#  6   Código do Fabricante          0 non-null      float64
#  7   Código de Barras              1047 non-null   int64
#  8   SKU Monitorado                1047 non-null   int64
#  9   Website Monitorado            1047 non-null   str
#  10  URL Produto Monitorado        1047 non-null   str
#  11  Data                          1047 non-null   datetime64[us]
#  12  Média Preço Normal            908 non-null    float64
# ...

# %%
base_limpa = base.drop(columns=[
    "Famlíia",
    "Código do Fabricante",
    "URL Monitor",
    "Desvio Média Preço %"
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 base_limpa = base.drop(columns=[
#       2     "Famlíia",
#       3     "Código do Fabricante",
#       4     "URL Monitor",
#       5     "Desvio Média Preço %"
#       6 ])
#
# NameError: name 'base' is not defined

# %%
base_limpa = base_limpa.dropna(subset=["Média Preço Normal"])

# %%
base_limpa["Website Monitorado"].value_counts()
# Out:
# Website Monitorado
# www.paodeacucar.com    908
# Name: count, dtype: int64

# %%
base_limpa["Código"].nunique()
# Out:
# 336

# %%
base_recente = (
    base_limpa
    .sort_values("Data")
    .groupby("Código")
    .last()
    .reset_index()
)

# %%
base_recente.head()
# Out:
#    Código                                          Descrição Departamento  \
# 0  106498  Café Torrado e Moído Tradicional Café Brasilei...    Alimentos
# 1  183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
# 2  250665  Café Torrado e Moído Tradicional Caboclo Pacot...    Alimentos
# 3  250672  Café Solúvel Granulado Extraforte Nescafé Orig...    Alimentos
# 4  250702  Café Torrado e Moído Tradicional Pilão Pacote ...          NaN
#
#       Categoria/Setor            Marca  Código de Barras  SKU Monitorado  \
# 0  Básico da despensa  Café Brasileiro     7891018001386          106498
# 1  Básico da despensa               pa     7896005801529          183567
# 2  Básico da despensa          Caboclo     7896089011470          250665
# 3  Básico da despensa               pa     7891000300503          250672
# 4                 NaN            Pilão     7896089011982          250702
#
#     Website Monitorado                             URL Produto Monitorado  \
# ...

# %%
base_cafe.to_csv("base_cafe.csv", index=False)
