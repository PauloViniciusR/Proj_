# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

mambo = pd.read_csv("base/mambo.csv")
marche = pd.read_csv("base/marche.csv")
base_cafe = pd.read_csv("base/base_cafe.csv")

# %%
mambo.head()
# Out:
#     SKU                                             Titulo  Fabricante  \
# 0  2532         Café Torrado e Moído Superior Aviação 500g     Aviação
# 1  2533  Café Torrado e Moído 252 Graus a Vácuo Pilão 500g       Pilão
# 2  2534  Café Torrado e Moído 252° Graus Abre & Fecha P...       Pilão
# 3  2536  Café Torrado e Moído a Vácuo Tradicional 3 Cor...  3 Corações
# 4  2537  Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...     Delta Q
#
#    Categoria Disponibilidade  Preco  Preço Oferta  \
# 0  Mercearia      Disponivel  54.98         54.98
# 1  Mercearia      Disponivel  43.49         43.49
# 2  Mercearia      Disponivel  43.49         43.49
# 3  Mercearia      Disponivel  27.99         27.99
# 4  Mercearia      Disponivel  28.49         28.49
#
#                                                  URL
# 0  https://www.mambo.com.br/cafe-superior-moido-a...
# 1  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 2  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 3  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 4  https://www.mambo.com.br/cafe-aqtivus-8-delta-...

# %%
marche.head()
# Out:
#         SKU                                             Titulo Fabricante  \
# 0  20026827     Cápsulas de Café Illy Descafeinado 18 Unidades       Illy
# 1  20060012  Café L'or Torrado e Moído Equilibrado Torras G...        Lor
# 2  20055865      Cápsula de Café ORFEU Intenso Dolce Gusto 90g      Orfeu
# 3  20031287  Café em Cápsula L'or Torrado e Moído Lungo Esp...        Lor
# 4  20063958  Cápsulas de Café Baobá Especial Intenso 10 Uni...      Baobá
#
#   Categoria Disponibilidade  Preco  Preço Oferta  \
# 0      Café      Disponivel  71.29         71.29
# 1      Café      Disponivel  30.49         30.49
# 2      Café      Disponivel  32.49         32.49
# 3      Café      Disponivel  30.99         30.99
# 4      Café      Disponivel  35.69         35.69
#
#                                                  URL
# 0  https://marche.com.br/collections/mercearia/pr...
# 1  https://marche.com.br/collections/mercearia/pr...
# 2  https://marche.com.br/collections/mercearia/pr...
# 3  https://marche.com.br/collections/mercearia/pr...
# 4  https://marche.com.br/collections/mercearia/pr...

# %%
base_cafe.head()
# Out:
#     Código                                          Descrição Departamento  \
# 0  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 1  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 2  1038723  Café Torrado e Moído Extraforte Pilão Pacote 500g    Alimentos
# 3   183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
# 4   183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
#
#       Categoria/Setor Marca  Famlíia  Código do Fabricante  Código de Barras  \
# 0  Básico da despensa    pa      NaN                   NaN     7896089013399
# 1  Básico da despensa    pa      NaN                   NaN     7896089013399
# 2  Básico da despensa    pa      NaN                   NaN     7896089013399
# 3  Básico da despensa    pa      NaN                   NaN     7896005801529
# 4  Básico da despensa    pa      NaN                   NaN     7896005801529
#
#    SKU Monitorado   Website Monitorado  \
# 0         1038723  www.paodeacucar.com
# 1         1038723  www.paodeacucar.com
# 2         1038723  www.paodeacucar.com
# 3          183567  www.paodeacucar.com
# 4          183567  www.paodeacucar.com
#
#                               URL Produto Monitorado        Data  \
# 0  https://www.paodeacucar.com/produto/292186/caf...  2026-03-08
# 1  https://www.paodeacucar.com/produto/292186/caf...  2026-03-07
# 2  https://www.paodeacucar.com/produto/292186/caf...  2026-03-06
# 3  https://www.paodeacucar.com/produto/57156/cafe...  2026-03-08
# 4  https://www.paodeacucar.com/produto/57156/cafe...  2026-03-07
#
#    Média Preço Normal  Média Preço Oferta  Leituras  \
# 0               27.49               27.49        22
# 1               27.49               27.49        24
# 2               27.49               27.49        24
# 3               27.99               27.99        22
# 4               27.99               27.99        24
#
#    Leituras com disponibilidade  \
# 0                            22
# 1                            24
# 2                            17
# 3                            22
# 4                            23
#
#                                          URL Monitor  Desvio Média Preço %  \
# 0  https://monitor.precifica.com.br/index.php/Pro...                  28.4
# 1  https://monitor.precifica.com.br/index.php/Pro...                  28.4
# 2  https://monitor.precifica.com.br/index.php/Pro...                  28.4
# 3  https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 4  https://monitor.precifica.com.br/index.php/Pro...                   NaN
#
#    Marca Target
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
mambo.shape
marche.shape
base_cafe.shape
# Out:
# (1047, 19)

# %%
base_total = pd.concat([base_cafe, mambo, marche], ignore_index=True)

# %%
base_total[base_total["Loja"] == "Mambo"]
# Out:
#                                                 Titulo       Fabricante  \
# 349         Café Torrado e Moído Superior Aviação 500g          Aviação
# 350  Café Torrado e Moído 252 Graus a Vácuo Pilão 500g            Pilão
# 351  Café Torrado e Moído 252° Graus Abre & Fecha P...            Pilão
# 352  Café Torrado e Moído a Vácuo Tradicional 3 Cor...       3 Corações
# 353  Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...          Delta Q
# ..                                                 ...              ...
# 800  Café Torrado e Moído Aroma de Baunilha Baggio ...           Baggio
# 801  Café Torrado e Moído Mantiqueira de Minas Café...  Café Brasileiro
# 802  Café Torrado e Moído Mogiana Paulista Café Bra...  Café Brasileiro
# 803  Café Torrado e Moído Caparaó Café Brasileiro G...  Café Brasileiro
# 804                     Café Cremoso Nescafé Lata 150g          Nescafé
#
#      Preco   Loja Faixa_Preco marca_grupo
# 349  54.98  Mambo   (50, 100]      Outros
# 350  43.49  Mambo    (40, 50]       Pilão
# 351  43.49  Mambo    (40, 50]       Pilão
# 352  27.99  Mambo    (20, 30]  3 Corações
# 353  28.49  Mambo    (20, 30]      Outros
# ..     ...    ...         ...         ...
# 800  46.49  Mambo    (40, 50]      Outros
# 801  25.99  Mambo    (20, 30]      Outros
# 802  25.99  Mambo    (20, 30]      Outros
# 803  25.99  Mambo    (20, 30]      Outros
# 804  27.98  Mambo    (20, 30]     Nescafé
#
# [456 rows x 6 columns]

# %%
base_recente = (
    base_cafe
    .sort_values("Data")
    .groupby("Código")
    .last()
    .reset_index()
)

# %%
base_recente.groupby("Marca")["Média Preço Normal"].mean().sort_values()
# Out:
# Marca
# Café União Pouch 250g    16.990000
# Café Brasileiro          19.590000
# Embafreezer              19.980000
# do Ponto                 19.990000
# Qualitá Exclusive        22.623333
# Genérico                 22.990000
# Nescafé                  23.610000
# Bravo Cafe               23.786667
# Qualitá                  24.121818
# Astro Cafe               24.890000
# L'Or                     25.790000
# Tres Coracoes            25.990000
# Nescafé Gold             26.891429
# L'OR                     26.982800
# Três                     26.990000
# União                    27.215000
# QUALITA                  28.390000
# Nescafé Dolce Gusto      28.677407
# Café do Ponto            28.823333
# Illy                     29.691818
# Melitta                  29.990000
# Pilão                    30.081905
# Baggio                   30.284118
# pa                       30.476207
# C Annata                 30.990000
# 3 Corações               31.507632
# Native                   31.990000
# Santa Monica             33.617692
# Café do Centro           33.990000
# Premiado                 34.990000
# Caboclo                  34.990000
# ORFEU                    35.010000
# Juan Valdez              35.467500
# Starbucks                35.987500
# Prima Qualitá            38.740000
# Bravo                    38.990000
# Taeq                     39.990000
# Moderato                 39.990000
# 3 Chá                    39.990000
# Orfeu                    40.975000
# Constantino              41.536000
# Name: Média Preço Normal, dtype: float64

# %%
base_recente["Marca"].value_counts()
# Out:
# Marca
# 3 Corações               39
# pa                       30
# Nescafé Dolce Gusto      28
# L'OR                     25
# Pilão                    23
# Qualitá                  22
# Nescafé                  20
# Orfeu                    18
# Baggio                   17
# Illy                     13
# Santa Monica             13
# União                    13
# Starbucks                 8
# Nescafé Gold              7
# L'Or                      7
# Native                    5
# Juan Valdez               5
# Astro Cafe                5
# Constantino               5
# ORFEU                     5
# Melitta                   4
# Bravo Cafe                4
# Café Brasileiro           3
# Caboclo                   3
# Café do Ponto             3
# Três                      3
# Qualitá Exclusive         3
# Café do Centro            2
# Café União Pouch 250g     2
# 3 Chá                     2
# Prima Qualitá             2
# do Ponto                  1
# Taeq                      1
# C Annata                  1
# Tres Coracoes             1
# Bravo                     1
# Genérico                  1
# Moderato                  1
# Embafreezer               1
# Premiado                  1
# QUALITA                   1
# Name: count, dtype: int64

# %%
base_recente["Média Preço Normal"].hist(bins=20)

plt.title("Distribuição de preço do café")
plt.xlabel("Preco")
plt.ylabel("Quantidade")

plt.show()

# %%
base_recente.groupby("Website Monitorado")["Média Preço Normal"].mean()
# Out:
# Website Monitorado
# www.paodeacucar.com    29.848036
# Name: Média Preço Normal, dtype: float64

# %%
base_recente = base_recente.rename(columns={
    "Descrição": "Titulo",
    "Marca": "Fabricante",
    "Média Preço Normal": "Preco",
    "Website Monitorado": "Loja"
})

print(base_recente)
# Out:
#       Código                                             Titulo Departamento  \
# 0     106498  Café Torrado e Moído Tradicional Café Brasilei...    Alimentos
# 1     183567  Café Torrado e Moído Extraforte 3 Corações Pac...    Alimentos
# 2     250665  Café Torrado e Moído Tradicional Caboclo Pacot...    Alimentos
# 3     250672  Café Solúvel Granulado Extraforte Nescafé Orig...    Alimentos
# 4     250702  Café Torrado e Moído Tradicional Pilão Pacote ...          NaN
# ..       ...                                                ...          ...
# 344  7641688    Café Torrado e Moído Pilão 252 Graus Pouch 500g          NaN
# 345  7757617  Café Torrado e Moído Baggio Caffé.com Premium ...          NaN
# 346  8322463  Café com Leite Solúvel Clássico Melitta Lata 200g          NaN
# 347  8704672  Café Torrado em Grãos Espresso 3 Corações Gour...    Alimentos
# 348  8888341  Café Solúvel em Pó Espresso Intenso Nescafé Go...          NaN
#
#         Categoria/Setor       Fabricante  Famlíia  Código do Fabricante  \
# 0    Básico da despensa  Café Brasileiro      NaN                   NaN
# 1    Básico da despensa               pa      NaN                   NaN
# 2    Básico da despensa          Caboclo      NaN                   NaN
# 3    Básico da despensa               pa      NaN                   NaN
# 4                   NaN            Pilão      NaN                   NaN
# ..                  ...              ...      ...                   ...
# 344                 NaN            Pilão      NaN                   NaN
# 345                 NaN           Baggio      NaN                   NaN
# 346                 NaN          Melitta      NaN                   NaN
# 347  Básico da despensa       3 Corações      NaN                   NaN
# 348                 NaN           Native      NaN                   NaN
#
#      Código de Barras  SKU Monitorado                 Loja  \
# 0       7891018001386          106498  www.paodeacucar.com
# 1       7896005801529          183567  www.paodeacucar.com
# 2       7896089011470          250665  www.paodeacucar.com
# 3       7891000300503          250672  www.paodeacucar.com
# 4       7896089011982          250702  www.paodeacucar.com
# ..                ...             ...                  ...
# 344     7896089013856         7641688  www.paodeacucar.com
# 345     7898922711448         7757617  www.paodeacucar.com
# 346     7891021007573         8322463  www.paodeacucar.com
# 347     7896005800379         8704672  www.paodeacucar.com
# 348     7898206501161         8888341  www.paodeacucar.com
#
#                                 URL Produto Monitorado        Data   Preco  \
# 0    https://www.paodeacucar.com/produto/62071/cafe...  2026-03-08    7.79
# 1    https://www.paodeacucar.com/produto/57156/cafe...  2026-03-08   27.99
# 2    https://www.paodeacucar.com/produto/152018/caf...  2026-03-08   34.99
# 3    https://www.paodeacucar.com/produto/152381/caf...  2026-03-08   27.19
# 4    https://www.paodeacucar.com/produto/152472/caf...  2026-03-08   27.99
# ..                                                 ...         ...     ...
# 344  https://www.paodeacucar.com/produto/446736/caf...  2026-03-08   36.99
# 345  https://www.paodeacucar.com/produto/470052/caf...  2026-03-08   24.99
# 346  https://www.paodeacucar.com/produto/75674/cafe...  2026-03-08   16.99
# 347  https://www.paodeacucar.com/produto/218951/caf...  2026-03-08  149.90
# 348  https://www.paodeacucar.com/produto/153531/caf...  2026-03-08     NaN
#
#      Média Preço Oferta  Leituras  Leituras com disponibilidade  \
# 0                  7.79        22                             1
# 1                 27.99        22                            22
# 2                 34.99        22                            11
# 3                 27.19        22                            22
# 4                 27.99        23                            22
# ..                  ...       ...                           ...
# 344               36.99        22                            22
# 345               24.99        23                            23
# 346               16.99        22                             4
# 347              149.90        22                            22
# 348                 NaN        22                             0
#
#                                            URL Monitor  Desvio Média Preço %  \
# 0    https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 1    https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 2    https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 3    https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 4    https://monitor.precifica.com.br/index.php/Pro...                   NaN
# ..                                                 ...                   ...
# 344  https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 345  https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 346  https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 347  https://monitor.precifica.com.br/index.php/Pro...                   NaN
# 348  https://monitor.precifica.com.br/index.php/Pro...                   NaN
#
#      Marca Target
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 344         False
# 345          True
# 346         False
# 347         False
# 348         False
#
# [349 rows x 19 columns]

# %%
mambo = mambo.rename(columns={
    "Titulo": "Titulo",
    "Fabricante": "Fabricante",
    "Preco": "Preco"
})

mambo["Loja"] = "Mambo"

mambo = mambo[["Titulo","Fabricante","Preco","Loja"]]
print(mambo)
# Out:
#                                                 Titulo       Fabricante  \
# 0           Café Torrado e Moído Superior Aviação 500g          Aviação
# 1    Café Torrado e Moído 252 Graus a Vácuo Pilão 500g            Pilão
# 2    Café Torrado e Moído 252° Graus Abre & Fecha P...            Pilão
# 3    Café Torrado e Moído a Vácuo Tradicional 3 Cor...       3 Corações
# 4    Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...          Delta Q
# ..                                                 ...              ...
# 451  Café Torrado e Moído Aroma de Baunilha Baggio ...           Baggio
# 452  Café Torrado e Moído Mantiqueira de Minas Café...  Café Brasileiro
# 453  Café Torrado e Moído Mogiana Paulista Café Bra...  Café Brasileiro
# 454  Café Torrado e Moído Caparaó Café Brasileiro G...  Café Brasileiro
# 455                     Café Cremoso Nescafé Lata 150g          Nescafé
#
#      Preco   Loja
# 0    54.98  Mambo
# 1    43.49  Mambo
# 2    43.49  Mambo
# 3    27.99  Mambo
# 4    28.49  Mambo
# ..     ...    ...
# 451  46.49  Mambo
# 452  25.99  Mambo
# 453  25.99  Mambo
# 454  25.99  Mambo
# 455  27.98  Mambo
#
# [456 rows x 4 columns]

# %%
marche["Loja"] = "St Marche"

marche = marche[["Titulo","Fabricante","Preco","Loja"]]

base_recente = base_recente[["Titulo","Fabricante","Preco","Loja"]]

# %%
base_total = pd.concat([base_recente, mambo, marche], ignore_index=True)

# %%
base_total.groupby("Fabricante")["Preco"].mean()
# Out:
# Fabricante
# 3 Chá         39.990000
# 3 Corações    28.736865
# Astro Cafe    24.890000
# Aviação       54.980000
# Baggio        33.214286
#                 ...
# Três          26.990000
# União         25.970000
# Villa Piva    40.690000
# do Ponto      19.990000
# pa            30.476207
# Name: Preco, Length: 77, dtype: float64

# %%
pd.crosstab(base_total["Fabricante"], base_total["Loja"])
# Out:
# Loja        Mambo  St Marche  www.paodeacucar.com
# Fabricante
# 3 Chá           0          0                    2
# 3 Corações     85         62                   39
# Astro Cafe      0          0                    5
# Aviação         2          0                    0
# Baggio         18         14                   17
# ...           ...        ...                  ...
# Três            0          0                    3
# União           9          3                   13
# Villa Piva      0          3                    0
# do Ponto        0          0                    1
# pa              0          0                   30
#
# [77 rows x 3 columns]

# %%
base_total.pivot_table(
    index="Titulo",
    columns="Loja",
    values="Preco"
)
# Out:
# Loja                                                 Mambo  St Marche  \
# Titulo
# CAFÉ FAZENDA PESSEGUEIRO Torra Média Cápsulas c...     NaN      37.19
# Cafe 3 Corações Torrado e Moído Rituais Frutas ...     NaN      40.99
# Cafe Capsula Torra Italiana Display Com 10 Unid...     NaN        NaN
# Cafe Soluvel com Leite Descafeinado Sem Lactose...   28.98        NaN
# Cafe Torrado em Grãos Acauã Orfeu Varietais Pac...     NaN        NaN
# ...                                                    ...        ...
# Cápsulas de Cappuccino Napolitano 3 Corações 11...   17.98        NaN
# Drip Coffee - Qualitá Premium 100g                     NaN        NaN
# Especial de Café 180g                                  NaN        NaN
# Kit Cápsula de Café + Caneca Nespresso & Starbu...  127.49        NaN
# Kit Cáspsula de Café STARBUCK 4 Unidades Com Um...     NaN     119.90
#
# Loja                                                www.paodeacucar.com
# Titulo
# CAFÉ FAZENDA PESSEGUEIRO Torra Média Cápsulas c...                  NaN
# Cafe 3 Corações Torrado e Moído Rituais Frutas ...                  NaN
# Cafe Capsula Torra Italiana Display Com 10 Unid...                27.99
# Cafe Soluvel com Leite Descafeinado Sem Lactose...                  NaN
# Cafe Torrado em Grãos Acauã Orfeu Varietais Pac...                46.99
# ...                                                                 ...
# Cápsulas de Cappuccino Napolitano 3 Corações 11...                  NaN
# Drip Coffee - Qualitá Premium 100g                                22.99
# Especial de Café 180g                                             22.99
# Kit Cápsula de Café + Caneca Nespresso & Starbu...                  NaN
# Kit Cáspsula de Café STARBUCK 4 Unidades Com Um...                  NaN
#
# [1049 rows x 3 columns]

# %%
comparacao = base_total.pivot_table(
    index="Titulo",
    columns="Loja",
    values="Preco"
)

comparacao.head(20)
# Out:
# Loja                                                Mambo  St Marche  \
# Titulo
# CAFÉ FAZENDA PESSEGUEIRO Torra Média Cápsulas c...    NaN      37.19
# Cafe 3 Corações Torrado e Moído Rituais Frutas ...    NaN      40.99
# Cafe Capsula Torra Italiana Display Com 10 Unid...    NaN        NaN
# Cafe Soluvel com Leite Descafeinado Sem Lactose...  28.98        NaN
# Cafe Torrado em Grãos Acauã Orfeu Varietais Pac...    NaN        NaN
# Café 3 CORAÇÕES Cápsulas Espresso Supremo Com 1...    NaN      26.90
# Café 3 CORAÇÕES Cápsulas Espresso Vibrante Com ...    NaN      26.90
# Café 3 CORAÇÕES Solúvel Liofilizado 100% Arábic...    NaN      35.99
# Café 3 Corações Grãos Rituais Frutas Secas 250g       NaN      47.89
# Café 3 Corações Portinari Florais 250g                NaN      36.98
# Café 3 Corações Solúvel 1957 100g                     NaN      38.90
# Café 3 Corações Torrado e Moído Rituais Chocola...    NaN      40.99
# Café 3 Corações Torrado e Moído Rituais Exótico...    NaN      40.99
# Café 3 Corações Torrado e Moído Rituais Frutas ...    NaN      40.99
# Café 3 Corações em Cápsulas Napolitano 8 Unidades     NaN      26.90
# Café 3 Corações em Cápsulas Rituais Exótico 8 U...    NaN      26.90
# Café BAGGIO Aromas Caramelo Torrado e Moído 250g      NaN      42.49
# Café BAGGIO Aromas Chocolate Trufado Torrado e ...    NaN      42.49
# Café BAGGIO Torrado e Moído Chocolate com Avelã...    NaN      42.49
# Café BRAVO Maestro Torrado Moído 250g                 NaN      28.49
#
# Loja                                                www.paodeacucar.com
# Titulo
# CAFÉ FAZENDA PESSEGUEIRO Torra Média Cápsulas c...                  NaN
# Cafe 3 Corações Torrado e Moído Rituais Frutas ...                  NaN
# Cafe Capsula Torra Italiana Display Com 10 Unid...                27.99
# Cafe Soluvel com Leite Descafeinado Sem Lactose...                  NaN
# Cafe Torrado em Grãos Acauã Orfeu Varietais Pac...                46.99
# Café 3 CORAÇÕES Cápsulas Espresso Supremo Com 1...                  NaN
# Café 3 CORAÇÕES Cápsulas Espresso Vibrante Com ...                  NaN
# Café 3 CORAÇÕES Solúvel Liofilizado 100% Arábic...                  NaN
# Café 3 Corações Grãos Rituais Frutas Secas 250g                     NaN
# Café 3 Corações Portinari Florais 250g                              NaN
# Café 3 Corações Solúvel 1957 100g                                   NaN
# Café 3 Corações Torrado e Moído Rituais Chocola...                  NaN
# Café 3 Corações Torrado e Moído Rituais Exótico...                  NaN
# Café 3 Corações Torrado e Moído Rituais Frutas ...                  NaN
# Café 3 Corações em Cápsulas Napolitano 8 Unidades                   NaN
# Café 3 Corações em Cápsulas Rituais Exótico 8 U...                  NaN
# Café BAGGIO Aromas Caramelo Torrado e Moído 250g                    NaN
# Café BAGGIO Aromas Chocolate Trufado Torrado e ...                  NaN
# Café BAGGIO Torrado e Moído Chocolate com Avelã...                  NaN
# Café BRAVO Maestro Torrado Moído 250g                               NaN

# %%
base_total.groupby("Loja")["Titulo"].count()
# Out:
# Loja
# Mambo                  456
# St Marche              282
# www.paodeacucar.com    349
# Name: Titulo, dtype: int64

# %%
base_total.groupby("Loja")["Preco"].mean().sort_values(ascending=False)
# Out:
# Loja
# St Marche              36.006206
# Mambo                  34.097632
# www.paodeacucar.com    29.848036
# Name: Preco, dtype: float64

# %% [markdown]
# A análise de preços de café entre os supermercados
# indica diferenças claras de posicionamento. O St Marche
# apresenta o maior preço médio R$36 e mediana de R$31,
# sugerindo presença significativa de produtos premium.

# %%
base_total.groupby("Loja")["Preco"].median().sort_values()
# Out:
# Loja
# www.paodeacucar.com    27.965
# Mambo                  29.900
# St Marche              31.990
# Name: Preco, dtype: float64

# %% [markdown]
# - St Marche é o supermercado mais premium
#
# - Pão de Açúcar tem preços mais competitivos

# %%
analise_loja = (
    base_total
    .groupby("Loja")["Preco"]
    .agg(["mean","median","min","max","count"])
    .reset_index()
)

analise_loja
# Out:
#                   Loja       mean  median   min     max  count
# 0                Mambo  34.097632  29.900  3.59  194.98    456
# 1            St Marche  36.006206  31.990  2.99  165.29    282
# 2  www.paodeacucar.com  29.848036  27.965  2.99  149.90    336

# %%
#analise_loja.to_csv("results/analise_preco_loja.csv", index=False)

# %%
analise_fabricante = (
    base_total.groupby("Fabricante")["Preco"]
    .agg(["mean","median","min","max","count"])
    .sort_values("mean")
    .reset_index()
)

# Calcular range
analise_fabricante["range"] = (analise_fabricante["max"] - analise_fabricante["min"]).round(2)

# Arredondar
analise_fabricante[["mean","median","min","max"]] = analise_fabricante[["mean","median","min","max"]].round(2)

# %%
#analise_fabricante.to_csv("results/analise_preco_fabricante.csv", index=False)

# %%
analise_mix = pd.crosstab(
    base_total["Fabricante"], base_total["Loja"]
)

analise_mix
# Out:
# Loja        Mambo  St Marche  www.paodeacucar.com
# Fabricante
# 3 Chá           0          0                    2
# 3 Corações     85         62                   39
# Astro Cafe      0          0                    5
# Aviação         2          0                    0
# Baggio         18         14                   17
# ...           ...        ...                  ...
# Três            0          0                    3
# União           9          3                   13
# Villa Piva      0          3                    0
# do Ponto        0          0                    1
# pa              0          0                   30
#
# [77 rows x 3 columns]

# %%
#analise_mix.to_csv("results/analise_mix.csv")

# %%
analise_preco = base_total["Preco"].describe().round(2)

analise_preco
# Out:
# count    1074.00
# mean       33.27
# std        19.61
# min         2.99
# 25%        24.92
# 50%        29.90
# 75%        38.49
# max       194.98
# Name: Preco, dtype: float64

# %%
#analise_preco.to_csv("results/analise_distribuicao_preco.csv")

# %%
bins = [0,20,30,40,50,100]

base_total["Faixa_Preco"] = pd.cut(base_total["Preco"], bins=bins)

base_total["Faixa_Preco"].value_counts().sort_index(ascending=True)
# Out:
# Faixa_Preco
# (0, 20]      177
# (20, 30]     391
# (30, 40]     271
# (40, 50]     143
# (50, 100]     73
# Name: count, dtype: int64

# %%
top_marcas = (
    base_total.groupby("Fabricante")["Preco"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
)

top_marcas.plot(kind="bar")
# Out:
# <Axes: xlabel='Fabricante'>

# %%
top_marcas = (
    base_total.groupby("Fabricante")["Preco"]
    .mean()
    .sort_values(ascending=True)
    .head(5)
)

top_marcas.plot(kind="bar")
# Out:
# <Axes: xlabel='Fabricante'>

# %%
top = base_total["Fabricante"].value_counts().head(5).index

base_total["marca_grupo"] = base_total["Fabricante"].apply(
    lambda x: x if x in top else "Outros"
)

sns.histplot(base_total["Preco"], bins=30);

# %%
plt.figure(figsize=(12, 6))

sns.kdeplot(base_total["Preco"], fill=True, bw_adjust=0.7, color="skyblue")

plt.axvline(base_total["Preco"].median(), color="red", linestyle="solid", label="Mediana")
plt.axvline(base_total["Preco"].mean(), color="red", linestyle="dotted", label="Média")

plt.title("Distribuição de preços KDE")
plt.xlabel("Preço")
plt.xticks(np.arange(0, 210, 10))
plt.ylabel("Densidade")
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
media = base_total['Preco'].mean()
std = base_total['Preco'].std()

# Produtos dentro da faixa ±1 std
dentro_1std = base_total[(base_total['Preco'] >= media - std) & (base_total['Preco'] <= media + std)]

# Porcentagem real
percent_dentro_1std = len(dentro_1std) / len(base_total) * 100
print(f'Percentual real dentro de ±1 std: {percent_dentro_1std:.2f}%')
# Out:
# Percentual real dentro de ±1 std: 85.74%

# %% [markdown]
# A maior parte dos produtos está concentrada na faixa ±1 std.
#
# Os outliers (muito baratos ou caros) distorcem a média, mas são poucos.
#
# A mediana é mais representativa do preço típico da maioria dos produtos.

# %%
media = base_total['Preco'].mean()
mediana = base_total['Preco'].median()
std = base_total['Preco'].std()

lower = media - std
upper = media + std

dentro_1std = base_total[(base_total['Preco'] >= lower) & (base_total['Preco'] <= upper)]
percent_dentro_1std = len(dentro_1std) / len(base_total) * 100

plt.figure(figsize=(14,6))

# Curva KDE
sns.kdeplot(base_total['Preco'], fill=True, bw_adjust=0.7, color='#1f77b4', alpha=0.5)

# Faixas de preço
plt.axvspan(0, 10, color='#2ca02c', alpha=0.25, label='Barato (<R$10)')
plt.axvspan(10, 38, color='#17becf', alpha=0.25, label='Médio (R$10–38)')
plt.axvspan(38, base_total['Preco'].max(), color='#9467bd', alpha=0.25, label='Premium (>R$38)')

# Média e mediana
plt.axvline(media, color='#d62728', linestyle='--', linewidth=2, label=f'Média: {media:.2f}')
plt.axvline(mediana, color='black', linestyle='--', linewidth=2, label=f'Mediana: {mediana:.2f}')

# ±1 std
plt.axvline(lower, color='#ffbf00', linestyle='--', linewidth=1.5)
plt.axvline(upper, color='#ffbf00', linestyle='--', linewidth=1.5)

plt.fill_betweenx(
    y=[0, plt.gca().get_ylim()[1]],
    x1=lower,
    x2=upper,
    color='#ffbf00',
    alpha=0.15,
    label=f'±1 std ≈ {percent_dentro_1std:.2f}%'
)

plt.title('Distribuição de Preços e ±1 Desvio Padrão', fontsize=16)
plt.xlabel('Preço (R$)', fontsize=14)
plt.xticks(np.arange(0, 210, 10))
plt.ylabel('Densidade', fontsize=14)

plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# A maior parte dos produtos está concentrada em preços médios, o que indica que a estratégia de preço e estoque deve priorizar essa faixa.
#
# A faixa ±1 std cobre praticamente toda a distribuição central (85,74%), mostrando onde o consumidor típico encontra produtos.
#
# Produtos fora dessa faixa são exceções, que podem ser usados para promoções, ofertas de entrada ou produtos premium.
#
# Média > mediana → indica assimetria à direita, causada por produtos caros, então a mediana reflete melhor o preço típico do catálogo.
