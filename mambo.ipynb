# %%
import pandas as pd

arquivo = "base/base_cafe.xlsx"

mambo = pd.read_excel(arquivo, sheet_name="mambo")
marche = pd.read_excel(arquivo, sheet_name="marche")

mambo.head()
# Out:
#     SKU                                             Titulo  Fabricante  \
# 0  2532         Café Torrado e Moído Superior Aviação 500g     Aviação
# 1  2533  Café Torrado e Moído 252 Graus a Vácuo Pilão 500g       Pilão
# 2  2534  Café Torrado e Moído 252° Graus Abre & Fecha P...       Pilão
# 3  2536  Café Torrado e Moído a Vácuo Tradicional 3 Cor...  3 Corações
# 4  2537  Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...     Delta Q
#
#    Tipo Produto Departamento  Categoria  Sub Categoria           GTIN  Modelo  \
# 0           NaN        Mambo  Mercearia            NaN  7896331100648     NaN
# 1           NaN        Mambo  Mercearia            NaN  7896089013849     NaN
# 2           NaN        Mambo  Mercearia            NaN  7896089013856     NaN
# 3           NaN        Mambo  Mercearia            NaN  7896045102440     NaN
# 4           NaN        Mambo  Mercearia            NaN  5601082038537     NaN
#
#    Bytes  ...                                                 _3  \
# 0    NaN  ...                                                NaN
# 1    NaN  ...                                                NaN
# 2    NaN  ...  https://mambodelivery.vteximg.com.br/arquivos/...
# 3    NaN  ...  https://mambodelivery.vteximg.com.br/arquivos/...
# 4    NaN  ...                                                NaN
#
#                                                   _4  \
# 0                                                NaN
# 1                                                NaN
# 2  https://mambodelivery.vteximg.com.br/arquivos/...
# 3  https://mambodelivery.vteximg.com.br/arquivos/...
# 4                                                NaN
#
#                                                   _5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://mambodelivery.vteximg.com.br/arquivos/...
# 4                                                NaN
#
#                                                   _6  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://mambodelivery.vteximg.com.br/arquivos/...
# 4                                                NaN
#
#                                                   _7  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://mambodelivery.vteximg.com.br/arquivos/...
# 4                                                NaN
#
#                                                   _8   _9  _10  _11  \
# 0                                                NaN  NaN  NaN  NaN
# 1                                                NaN  NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN
# 3  https://mambodelivery.vteximg.com.br/arquivos/...  NaN  NaN  NaN
# 4                                                NaN  NaN  NaN  NaN
#
#    CLUSTER PAO
# 0          NaN
# 1          NaN
# 2    7641688.0
# 3          NaN
# 4          NaN
#
# [5 rows x 38 columns]

# %%
mambo.columns
# Out:
# Index(['SKU', 'Titulo', 'Fabricante', 'Tipo Produto', 'Departamento',
#        'Categoria', 'Sub Categoria', 'GTIN', 'Modelo', 'Bytes', 'Litros',
#        'Tamanho', 'Qtde. Pacote', 'Cor', 'Peso', 'Genero', 'Volume',
#        'Voltagem', 'Disponibilidade', 'Preco', 'Preço Oferta', 'Vendedor',
#        'Descricao', 'Descricao_1', 'URL', 'URL Imagem', 'URL Imagem_2',
#        'Column1', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11',
#        'CLUSTER PAO'],
#       dtype='str')

# %%
colunas_importantes_mambo = [
    "SKU",
    "Titulo",
    "Fabricante",
    "Categoria",
    "Disponibilidade",
    "Preco",
    "Preço Oferta",
    "URL"
]

mambo = mambo[colunas_importantes_mambo]

mambo.head()
# Out:
#     SKU                                             Titulo  Fabricante  \
# 0  2532         Café Torrado e Moído Superior Aviação 500g     Aviação
# 1  2533  Café Torrado e Moído 252 Graus a Vácuo Pilão 500g       Pilão
# 2  2534  Café Torrado e Moído 252° Graus Abre & Fecha P...       Pilão
# 3  2536  Café Torrado e Moído a Vácuo Tradicional 3 Cor...  3 Corações
# 4  2537  Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...     Delta Q
#
#    Categoria Disponibilidade  Preco  Preço Oferta  \
# 0  Mercearia      Disponivel  54.98         54.98
# 1  Mercearia      Disponivel  43.49         43.49
# 2  Mercearia      Disponivel  43.49         43.49
# 3  Mercearia      Disponivel  27.99         27.99
# 4  Mercearia      Disponivel  28.49         28.49
#
#                                                  URL
# 0  https://www.mambo.com.br/cafe-superior-moido-a...
# 1  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 2  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 3  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 4  https://www.mambo.com.br/cafe-aqtivus-8-delta-...

# %%
mambo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SKU              498 non-null    int64
#  1   Titulo           498 non-null    str
#  2   Fabricante       498 non-null    str
#  3   Categoria        498 non-null    str
#  4   Disponibilidade  498 non-null    str
#  5   Preco            498 non-null    float64
#  6   Preço Oferta     498 non-null    float64
#  7   URL              498 non-null    str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 31.3 KB

# %%
mambo["Fabricante"].unique()
# Out:
# <StringArray>
# [        'Aviação',           'Pilão',      '3 Corações',         'Delta Q',
#         'Floresta',      'Bravo Café',         'Nescafé',           'Orfeu',
#           'Italle',         'Melitta',    'Santa Mônica',            'Illy',
#              'Lor',          'Ituano',        'Evolutto',          'Native',
#    'Cafe Floresta',       'Café Pelé',     'Café Toledo',          'Baggio',
#     'Cia Organica',       'Starbucks',          'Iguaçu',          'Nestlé',
#      'Cafe Iguacu',   'Prima Qualita',   'Café do Ponto',         'Caboclo',
#          'Havanna',           'União',           'Camil',            'Fort',
#  'Café Brasileiro',      'Brasileiro',   'Caffè Corsini',       'Coffee ++',
#          'Lavazza',     'Juan Valdez',    'Santa Monica',         'Carraro',
#         'Bialetti',       'Luvizotto',          'Gaggia',        'Bauducco',
#             'Gold',           'Bravo']
# Length: 46, dtype: str

# %%
mambo["Fabricante"].value_counts()
# Out:
# Fabricante
# 3 Corações         92
# Nescafé            70
# Lor                39
# Orfeu              33
# Pilão              31
# Coffee ++          29
# Melitta            25
# Baggio             19
# Illy               15
# Bravo Café         10
# Santa Mônica       10
# Italle              9
# União               9
# Caffè Corsini       9
# Starbucks           8
# Nestlé              7
# Juan Valdez         7
# Delta Q             6
# Café Brasileiro     6
# Carraro             5
# Floresta            4
# Café Toledo         4
# Cia Organica        4
# Iguaçu              4
# Lavazza             4
# Santa Monica        4
# Ituano              3
# Native              3
# Café do Ponto       3
# Luvizotto           3
# Gold                3
# Aviação             2
# Evolutto            2
# Cafe Floresta       2
# Prima Qualita       2
# Bialetti            2
# Café Pelé           1
# Cafe Iguacu         1
# Caboclo             1
# Havanna             1
# Camil               1
# Fort                1
# Brasileiro          1
# Gaggia              1
# Bauducco            1
# Bravo               1
# Name: count, dtype: int64

# %%
mambo["Preco"] = pd.to_numeric(mambo["Preco"], errors="coerce")
mambo["Preço Oferta"] = pd.to_numeric(mambo["Preço Oferta"], errors="coerce")

# %%
mambo["Disponibilidade"].value_counts()
# Out:
# Disponibilidade
# Disponivel      456
# Indisponivel     42
# Name: count, dtype: int64

# %%
mambo = mambo[mambo["Disponibilidade"] == "Disponivel"] 
mambo.head()
# Out:
#     SKU                                             Titulo  Fabricante  \
# 0  2532         Café Torrado e Moído Superior Aviação 500g     Aviação
# 1  2533  Café Torrado e Moído 252 Graus a Vácuo Pilão 500g       Pilão
# 2  2534  Café Torrado e Moído 252° Graus Abre & Fecha P...       Pilão
# 3  2536  Café Torrado e Moído a Vácuo Tradicional 3 Cor...  3 Corações
# 4  2537  Cápsula de Café Aqtivus 8 Delta 55g com 10 Uni...     Delta Q
#
#    Categoria Disponibilidade  Preco  Preço Oferta  \
# 0  Mercearia      Disponivel  54.98         54.98
# 1  Mercearia      Disponivel  43.49         43.49
# 2  Mercearia      Disponivel  43.49         43.49
# 3  Mercearia      Disponivel  27.99         27.99
# 4  Mercearia      Disponivel  28.49         28.49
#
#                                                  URL
# 0  https://www.mambo.com.br/cafe-superior-moido-a...
# 1  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 2  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 3  https://www.mambo.com.br/cafe-torrado-e-moido-...
# 4  https://www.mambo.com.br/cafe-aqtivus-8-delta-...

# %%
mambo.shape
# Out:
# (498, 8)

# %%
mambo["Preco"].mean()
# Out:
# np.float64(31.221927710843374)

# %%
mambo.groupby("Fabricante")["Preco"].mean().sort_values()
# Out:
# Fabricante
# Bravo                0.000000
# Gaggia               0.000000
# Lavazza              0.000000
# Italle              15.878889
# Havanna             17.980000
# Floresta            19.980000
# Carraro             19.984000
# Native              19.986667
# União               20.646667
# Nescafé             20.759286
# Iguaçu              20.840000
# Bauducco            21.900000
# 3 Corações          22.575435
# Santa Mônica        25.139000
# Gold                25.320000
# Bravo Café          25.400000
# Camil               25.900000
# Nestlé              26.461429
# Lor                 27.187436
# Café Brasileiro     27.490000
# Melitta             27.687200
# Cafe Iguacu         27.990000
# Delta Q             28.490000
# Brasileiro          28.990000
# Fort                28.990000
# Cafe Floresta       34.980000
# Baggio              35.537368
# Caboclo             35.980000
# Coffee ++           36.903793
# Café Pelé           36.980000
# Pilão               38.228710
# Illy                39.050667
# Orfeu               39.909697
# Starbucks           46.671250
# Café Toledo         46.740000
# Cia Organica        49.107500
# Bialetti            49.235000
# Caffè Corsini       53.930000
# Aviação             54.980000
# Café do Ponto       55.980000
# Santa Monica        70.735000
# Juan Valdez         77.982857
# Evolutto            84.980000
# Prima Qualita       85.980000
# Ituano              87.980000
# Luvizotto          110.150000
# Name: Preco, dtype: float64

# %%
mambo.groupby("Fabricante")["Preco"].mean().sort_values(ascending=False)
# Out:
# Fabricante
# Luvizotto          110.150000
# Ituano              87.980000
# Prima Qualita       85.980000
# Evolutto            84.980000
# Juan Valdez         77.982857
# Santa Monica        70.735000
# Café do Ponto       55.980000
# Aviação             54.980000
# Caffè Corsini       53.930000
# Bialetti            49.235000
# Cia Organica        49.107500
# Café Toledo         46.740000
# Starbucks           46.671250
# Orfeu               39.909697
# Illy                39.050667
# Pilão               38.228710
# Café Pelé           36.980000
# Coffee ++           36.903793
# Caboclo             35.980000
# Baggio              35.537368
# Cafe Floresta       34.980000
# Brasileiro          28.990000
# Fort                28.990000
# Delta Q             28.490000
# Cafe Iguacu         27.990000
# Melitta             27.687200
# Café Brasileiro     27.490000
# Lor                 27.187436
# Nestlé              26.461429
# Camil               25.900000
# Bravo Café          25.400000
# Gold                25.320000
# Santa Mônica        25.139000
# 3 Corações          22.575435
# Bauducco            21.900000
# Iguaçu              20.840000
# Nescafé             20.759286
# União               20.646667
# Native              19.986667
# Carraro             19.984000
# Floresta            19.980000
# Havanna             17.980000
# Italle              15.878889
# Bravo                0.000000
# Gaggia               0.000000
# Lavazza              0.000000
# Name: Preco, dtype: float64

# %%
mambo.to_csv("mambo.csv", index=False)
